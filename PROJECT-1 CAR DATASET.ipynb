# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("car.csv")

# %%
data
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
results=data[["selling_price","km_driven"]].describe()
results["selling_price"]=results["selling_price"].astype("int")
results
# Out:
#        selling_price      km_driven
# count           4340    4340.000000
# mean          504127   66215.777419
# std           578548   46644.102194
# min            20000       1.000000
# 25%           208749   35000.000000
# 50%           350000   60000.000000
# 75%           600000   90000.000000
# max          8900000  806599.000000

# %%
data[data["selling_price"]==20000]
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 2662  Ford Ikon 1.6 ZXI NXt  2005          20000      25000  Petrol
#
#      seller_type transmission         owner Company
# 2662  Individual       Manual  Second Owner    Ford

# %%
data.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
data.index=data["name"]

# %%
data['Company']=data['name'].apply(lambda x:x.split(" ")[0])
data
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner  Company
# ...

# %%
results=data["Company"].value_counts()
results
# Out:
# Maruti           1280
# Hyundai           821
# Mahindra          365
# Tata              361
# Honda             252
# Ford              238
# Toyota            206
# Chevrolet         188
# Renault           146
# Volkswagen        107
# Skoda              68
# Nissan             64
# Audi               60
# BMW                39
# Fiat               37
# Datsun             37
# Mercedes-Benz      35
# Jaguar              6
# Mitsubishi          6
# Land                5
# Volvo               4
# Ambassador          4
# Jeep                3
# MG                  2
# OpelCorsa           2
# Daewoo              1
# Force               1
# Isuzu               1
# Kia                 1
# Name: Company, dtype: int64

# %%
data["fuel"].value_counts()
# Out:
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: fuel, dtype: int64

# %%
data[data['fuel']=="Electric"]
# Out:
#                      name  year  selling_price  km_driven      fuel  \
# 4145  Toyota Camry Hybrid  2006         310000      62000  Electric
#
#      seller_type transmission         owner
# 4145      Dealer    Automatic  Second Owner

# %%
results
# Out:
# Maruti           1280
# Hyundai           821
# Mahindra          365
# Tata              361
# Honda             252
# Ford              238
# Toyota            206
# Chevrolet         188
# Renault           146
# Volkswagen        107
# Skoda              68
# Nissan             64
# Audi               60
# BMW                39
# Fiat               37
# Datsun             37
# Mercedes-Benz      35
# Jaguar              6
# Mitsubishi          6
# Land                5
# Volvo               4
# Ambassador          4
# Jeep                3
# MG                  2
# OpelCorsa           2
# Daewoo              1
# Force               1
# Isuzu               1
# Kia                 1
# Name: Company, dtype: int64

# %%
results.plot.bar()
plt.show()

# %%
data[data['Company']=="Jeep"]
# Out:
#                                         name  year  selling_price  km_driven  \
# 40          Jeep Compass 1.4 Sport Plus BSIV  2019        1400000      10000
# 1325  Jeep Compass 2.0 Longitude Option BSIV  2018        1700000      50000
# 3790  Jeep Compass 2.0 Longitude Option BSIV  2017        1490000      22038
#
#         fuel seller_type transmission        owner Company
# 40    Petrol  Individual       Manual  First Owner    Jeep
# 1325  Diesel  Individual       Manual  First Owner    Jeep
# 3790  Diesel  Individual       Manual  First Owner    Jeep

# %%
results=data.groupby("Company")[["selling_price"]].mean()
results["selling_price"]=results["selling_price"].astype("int")
results.sort_values(by=["selling_price"])
# Out:
#                selling_price
# Company
# Daewoo                 60000
# OpelCorsa              88500
# Ambassador            180000
# Chevrolet             236727
# Fiat                  283432
# Tata                  284083
# Datsun                297026
# Maruti                342416
# Force                 346000
# Renault               419376
# Hyundai               419940
# Nissan                449937
# Volkswagen            471037
# Skoda                 490014
# Honda                 538146
# Ford                  571273
# Mahindra              587709
# Mitsubishi            840000
# Toyota                924359
# Kia                  1300000
# Isuzu                1500000
# Jeep                 1530000
# MG                   1842500
# Audi                 1931633
# Jaguar               2069166
# Volvo                2556250
# Mercedes-Benz        2776657
# BMW                  2945384
# Land                 3609800

# %%
results.plot.bar()
plt.show()

# %%
results=data.groupby("Company")[["km_driven"]].mean()
results.sort_values(by=["km_driven"])
results.plot.bar()
plt.show()

# %%
data["owner"].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Fourth & Above Owner',
#        'Third Owner', 'Test Drive Car'], dtype=object)

# %%
owner_count = data.groupby("owner")["owner"].count()
owner_count.plot.pie(autopct='%.2f%%', title="Pie chart") 
plt.show()

# %%
data["transmission"].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
transmission_count = data.groupby("transmission")["transmission"].count()
transmission_count.plot.pie(autopct='%.2f%%', title="Pie chart") 
plt.show()

# %%
plt.hist((data["year"].astype(int)))
plt.show()
